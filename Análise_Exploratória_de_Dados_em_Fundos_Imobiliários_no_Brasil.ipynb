# %% [markdown]
# <a href="https://colab.research.google.com/github/biangomes/Portfolio/blob/main/An%C3%A1lise_Explorat%C3%B3ria_de_Dados_em_Fundos_Imobili%C3%A1rios_no_Brasil.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **_Disclaimer_:** este trabalho é meramente **educativo** e **não possui nenhuma recomendação**.

# %% [markdown]
# ![capa.png](data:image/png;base64,...)

# %% [markdown]
# # Introdução

# %% [markdown]
# # Objetivos
#
# Este projeto trata-se de demonstrar a correlação entre os fundos imobiliários e listar os 3 fundos que tiveram maior retorno no período considerando a análise fundamentalista.

# %% [markdown]
# # Metódos

# %% [markdown]
# ### Conhecendo os dados
#
# Você pode encontrar os conjuntos de dados [aqui](https://www.kaggle.com/maverickjpa/fundos-imobiliarios-brasil-brazilian-funds-fiis).
#
# O primeiro arquivo, `FIIS_Hist.csv`, trata-se dos fundamentos de 184 fundos imobiliários brasileiros. As colunas são:
#
# - Data;
#
# - Fechamento;
#
# - Variação;
#
# - Variação (%);
#
# - Abertura;
#
# - Máxima;
#
# - Mínima;
#
# - Volume;
#
# - Cod Fundo

# %% [markdown]
# ### Código

# %%
# Importando as bibliotecas
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style();

# %%
# Salvando o caminho
path = "FIIS.csv"

# Salvando como dataframe
data = pd.read_csv(path, delimiter=';', low_memory=False);

# Visualizando as primeiras entradas
data.head()
# Out:
#   Códigodo fundo                Setor  ... VacânciaFinanceira  QuantidadeAtivos
# 0         FIVN11            Shoppings  ...                NaN                 1
# 1         BZLI11  Títulos e Val. Mob.  ...                NaN                 0
# 2         XTED11   Lajes Corporativas  ...            100,00%                 1
# 3         ALMI11   Lajes Corporativas  ...                NaN                 1
# 4         DOMC11   Lajes Corporativas  ...                NaN                 1
#
# [5 rows x 26 columns]

# %% [markdown]
# - Quantas entradas e variáveis o conjunto possui?

# %%
# Visualizando o tamanho do conj. de dados
print(f"O dataset possui {data.shape[0]} entradas e {data.shape[1]} variáveis.")

# Visualizando os dados do conj.
data.info()
# Out:
# O dataset possui 183 entradas e 26 variáveis.
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 183 entries, 0 to 182
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Códigodo fundo           183 non-null    object
#  1   Setor                    183 non-null    object
#  2   Preço Atual              181 non-null    object
#  3   Liquidez Diária          181 non-null    float64
#  4   Dividendo                183 non-null    object
#  5   DividendYield            183 non-null    object
#  6   DY (3M)Acumulado         183 non-null    object
#  7   DY (6M)Acumulado         183 non-null    object
#  8   DY (12M)Acumulado        183 non-null    object
#  9   DY (3M)Média             183 non-null    object
#  10  DY (6M)Média             183 non-null    object
#  11  DY (12M)Média            183 non-null    object
#  12  DY Ano                   180 non-null    object
# ...

# %% [markdown]
# ---
# # Conclusão
